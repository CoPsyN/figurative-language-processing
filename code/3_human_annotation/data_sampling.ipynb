# %%
import pandas as pd
import numpy as np
from sklearn.utils import shuffle
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# # 1. Read in the predicted labels

# %%
bert = pd.read_csv('../results/classification_results/predicted_labels_testset_bert-base-uncased.tsv', 
                   sep='\t')
roberta = pd.read_csv('../results/classification_results/predicted_labels_testset_roberta-base.tsv', 
                   sep='\t')
xlnet = pd.read_csv('../results/classification_results/predicted_labels_testset_xlnet-base-cased.tsv', 
                   sep='\t')
rf = pd.read_csv('../results/classification_results/predicted_labels_testset_rf.tsv', 
                   sep='\t')

lr = pd.read_csv('../results/classification_results/predicted_labels_testset_lr.tsv', 
                   sep='\t')

# %% [markdown]
# **Change the labels to consistent format:**
#
# The white-box models uses the encoding 1/2/3/4 for the four figurative language classes as in the dataset after preprocessing. However, for the black-box models, the encoding had to be changed to 0/1/2/3, because otherwise the transformer library doesn't work.
#
# Now change the encoding for the black-box models to 1/2/3/4.

# %%
bert['model'] = 'bert'
roberta['model'] = 'roberta'
xlnet['model'] = 'xlnet'
rf['model'] = 'rf'
lr['model'] = 'lr'

bert['pred'] = bert['pred'] + 1
bert['label'] = bert['label'] + 1

roberta['pred'] = roberta['pred'] + 1
roberta['label'] = roberta['label'] + 1

xlnet['pred'] = xlnet['pred'] + 1
xlnet['label'] = xlnet['label'] + 1

# %% [markdown]
# # 2. Get misclassified and correctly classified samples

# %% [markdown]
# ## 2.1 Misclassified

# %%
mis_bert = bert[bert['label'] != bert['pred']]
mis_roberta = roberta[roberta['label'] != roberta['pred']]
mis_xlnet = xlnet[xlnet['label'] != xlnet['pred']]
mis_rf = rf[rf['label'] != rf['pred']]
mis_lr = lr[lr['label'] != lr['pred']]

# %%
# number of misclassified examples by each model
print('bert-misclassified:')
print(len(mis_bert))
print('roberta-misclassified:')
print(len(mis_roberta))
print('xlnet-misclassified:')
print(len(mis_xlnet))
print('rf-misclassified:')
print(len(mis_rf))
print('lr-misclassified:')
print(len(mis_lr))
# Out:
# bert-misclassified:
# 28
# roberta-misclassified:
# 24
# xlnet-misclassified:
# 30
# rf-misclassified:
# 91
# lr-misclassified:
# 88

# %% [markdown]
# **Concatenate misclassified samples from all models:**

# %%
mis = pd.concat([mis_bert, mis_roberta, mis_xlnet, mis_rf, mis_lr], axis=0)
print(mis.drop_duplicates('text').value_counts('label'))
mis.drop_duplicates('text') # we have 136 misclassified examples in total.
# Out:
# label
# 2    72
# 4    47
# 3    10
# 1     7
# dtype: int64
#      label  \
# 23       4
# 34       4
# 48       2
# 59       4
# 78       4
# ..     ...
# 697      4
# 706      4
# 721      4
# 740      4
# 831      3
#
#                                                                                                                                           text  \
# 23                                                               I don't approve of political jokes; I have seen too many of them get elected.
# 34                                                                                                     Seems to be wide awake could of got up.
# 48                                                                                                            The situation was cut and dried.
# 59                                                  Primal Scream Not a name which would lead you to expect self-absorbed acoustic doodlings .
# 78                                                                 Paula perched herself against the cutting table trying to look nonchalant .
# ..                                                                                                                                         ...
# 697                                                                                                         She was dolled up yellow that day.
# 706                                                                                                She had to juggle her job and her children.
# 721                                                                                                  Though his pace he checked and slackened.
# 740                                                                                                      The play is going to burn few people.
# 831  She might look ruthless to the human eye, but sean could tell she was full of shame at being so stern with a man like a persistent puppy.
#
#      pred model
# 23      1  bert
# 34      2  bert
# 48      4  bert
# 59      2  bert
# 78      2  bert
# ..    ...   ...
# 697     1    lr
# 706     2    lr
# 721     2    lr
# 740     2    lr
# 831     2    lr
#
# [136 rows x 4 columns]

# %% [markdown]
# ## 2.2 Correctly classified

# %%
#well classified
good_bert = bert[bert['label'] == bert['pred']]
good_roberta = roberta[roberta['label'] == roberta['pred']]
good_xlnet = xlnet[xlnet['label'] == xlnet['pred']]
good_rf = rf[rf['label'] == rf['pred']]
good_lr = lr[lr['label'] == lr['pred']]

# %% [markdown]
# **Concatenate correctly classified samples from all models:**

# %%
good = pd.concat([good_bert, good_roberta, good_xlnet, good_rf, good_lr], axis=0)
good['label'].value_counts()
# Out:
# 1    2239
# 2     712
# 3     526
# 4     512
# Name: label, dtype: int64

# %% [markdown]
# # 3. Extract instances that are misclassified by at least two models

# %% [markdown]
# **Get how many models misclassified each example:**

# %%
mis_n_models = pd.DataFrame(mis.groupby('text')['model'].count()).stack().reset_index()
mis_n_models = mis_n_models.drop('level_1', axis=1)
mis_n_models = mis_n_models.rename(columns={0: "n_models"})
mis_n_models
# Out:
#                                                                                                                                                text  \
# 0                                                                                       A thought forms in my mind and it's like a sun-filled day .
# 1    After a couple of more songs, a familiar-looking blonde girl that had been trying to catch my eye all night asked me to play lips of an angel.
# 2                                                    After the vibrant colors of the garden, the stone hall seemed as dark and silent as the grave.
# 3                                                                                                    All fire-flush 'd when forest trees smoldered.
# 4                                                                           All new machines, even french ones, are apt to have teething troubles.”
# ..                                                                                                                                              ...
# 131                                                                                                                               the ayes have it.
# 132                                                                                                            this problem has migrated to the uk.
# 133                                                                                                                 tough titty, vamp,miranda said.
# 134                                                                                                     well don't turn it on too loud , will you ?
# 135                                                                                                                  your guess is as good as mine.
#
#      n_models
# 0           1
# 1           2
# 2           5
# 3           3
# 4           2
# ..        ...
# 131         2
# 132         1
# 133         1
# 134         4
# 135         2
#
# [136 rows x 2 columns]

# %%
mis_updated = mis.merge(mis_n_models, left_on='text', right_on='text')
mis_updated = mis_updated.drop_duplicates('text')
mis_updated['label'].value_counts()
# Out:
# 2    72
# 4    47
# 3    10
# 1     7
# Name: label, dtype: int64

# %%
mis_updated[mis_updated['n_models'] != 1].drop_duplicates('text')
# Out:
#      label  \
# 0        4
# 5        4
# 10       2
# 12       4
# 15       4
# ..     ...
# 222      4
# 224      2
# 226      2
# 229      2
# 232      2
#
#                                                                                                                                 text  \
# 0                                                      I don't approve of political jokes; I have seen too many of them get elected.
# 5                                                                                            Seems to be wide awake could of got up.
# 10                                                                                                  The situation was cut and dried.
# 12                                        Primal Scream Not a name which would lead you to expect self-absorbed acoustic doodlings .
# 15                                                       Paula perched herself against the cutting table trying to look nonchalant .
# ..                                                                                                                               ...
# 222                                                                                    And rest can never dwell , hope never  comes.
# 224  Hearing it full whack katherine felt proud being part of it despite her only contribution being that of providing the investor.
# 226                                      day in, day out, I work hard to put food on the table, and then I cop this from the missus.
# 229                                                                                                   your guess is as good as mine.
# 232                                                                      So women in medieval times were far from shrinking violets.
#
#      pred model  n_models
# 0       1  bert         5
# 5       2  bert         5
# 10      4  bert         2
# 12      2  bert         3
# 15      2  bert         2
# ..    ...   ...       ...
# 222     2    rf         2
# 224     1    rf         2
# 226     1    rf         2
# 229     3    rf         2
# 232     4    rf         2
#
# [72 rows x 5 columns]

# %%
mis_updated[mis_updated['n_models'] != 1].drop_duplicates('text').value_counts('label')
# Out:
# label
# 2    42
# 4    26
# 1     2
# 3     2
# dtype: int64

# %% [markdown]
# # 5. Sample 5 misclassified and 5 correctly classified instances for each class

# %% [markdown]
# ## 5.1 Misclassified

# %%
mis_to_select_from = mis_updated[mis_updated['n_models'] != 1]
print(mis_to_select_from['label'].value_counts())
mis_to_select_from
# Out:
# 2    42
# 4    26
# 3     2
# 1     2
# Name: label, dtype: int64
#      label  \
# 0        4
# 5        4
# 10       2
# 12       4
# 15       4
# ..     ...
# 222      4
# 224      2
# 226      2
# 229      2
# 232      2
#
#                                                                                                                                 text  \
# 0                                                      I don't approve of political jokes; I have seen too many of them get elected.
# 5                                                                                            Seems to be wide awake could of got up.
# 10                                                                                                  The situation was cut and dried.
# 12                                        Primal Scream Not a name which would lead you to expect self-absorbed acoustic doodlings .
# 15                                                       Paula perched herself against the cutting table trying to look nonchalant .
# ..                                                                                                                               ...
# 222                                                                                    And rest can never dwell , hope never  comes.
# 224  Hearing it full whack katherine felt proud being part of it despite her only contribution being that of providing the investor.
# 226                                      day in, day out, I work hard to put food on the table, and then I cop this from the missus.
# 229                                                                                                   your guess is as good as mine.
# 232                                                                      So women in medieval times were far from shrinking violets.
#
#      pred model  n_models
# 0       1  bert         5
# 5       2  bert         5
# 10      4  bert         2
# 12      2  bert         3
# 15      2  bert         2
# ..    ...   ...       ...
# 222     2    rf         2
# 224     1    rf         2
# 226     1    rf         2
# 229     3    rf         2
# 232     4    rf         2
#
# [72 rows x 5 columns]

# %%
sarc_mis = mis_to_select_from[mis_to_select_from['label'] == 1][['text', 'label', 'model']]
idiom_mis = mis_to_select_from[mis_to_select_from['label'] == 2].sample(7, random_state=45)[['text', 'label', 'model']]
simile_mis = mis_to_select_from[mis_to_select_from['label'] == 3][['text', 'label', 'model']]
metaphor_mis = mis_to_select_from[mis_to_select_from['label'] == 4].sample(7, random_state=45)[['text', 'label', 'model']]

# %% [markdown]
# **Add 5 random instances for sarcasm and simile:**

# %%
mis_to_add = mis_updated[mis_updated['n_models'] == 1].drop_duplicates('text')
sarc_mis_add = mis_to_add[mis_to_add['label'] == 1].sample(5, random_state=45)[['text', 'label', 'model']]
simile_mis_add = mis_to_add[mis_to_add['label'] == 3].sample(5, random_state=45)[['text', 'label', 'model']]

# %%
sarc_mis = pd.concat([sarc_mis, sarc_mis_add], axis=0)
simile_mis = pd.concat([simile_mis, simile_mis_add], axis=0)

# %% [markdown]
# ## 5.2 Correctly classified

# %%
good_n_models = pd.DataFrame(good.groupby('text')['model'].count()).stack().reset_index()
good_n_models = good_n_models.drop('level_1', axis=1)
good_n_models = good_n_models.rename(columns={0: "n_models"})
good_n_models
# Out:
#                                                                                                                        text  \
# 0                                                  "Cross my heart, buddy; I'm telling you the whole truth," Melanie swore.
# 1               A faint smile curved her lips, and then I heard her voice in my mind like a welcome breeze on a summer day.
# 2    A friend let me borrow his old headphones and now I feel terrific about my sense of responsibility because I lost them
# 3                                                               A thought forms in my mind and it's like a sun-filled day .
# 4                                                                                         A weather vane caps the building.
# ..                                                                                                                      ...
# 837                                                                                         tough titty, vamp,miranda said.
# 838                                                                                   we were sinking in an ocean of grass.
# 839                                                                             well don't turn it on too loud , will you ?
# 840                                                                                          your guess is as good as mine.
# 841                                            your guess is as good as mine; you know my visions do not reveal everything.
#
#      n_models
# 0           5
# 1           5
# 2           5
# 3           4
# 4           5
# ..        ...
# 837         4
# 838         5
# 839         1
# 840         3
# 841         5
#
# [842 rows x 2 columns]

# %%
good_n_models['n_models'].value_counts()
# Out:
# 5    714
# 4     64
# 3     42
# 2     15
# 1      7
# Name: n_models, dtype: int64

# %%
good_updated = good.merge(good_n_models, left_on='text', right_on='text')
good_updated[good_updated['n_models'] == 5].drop_duplicates('text')
# Out:
#       label  \
# 0         1
# 5         3
# 10        2
# 15        1
# 20        4
# ...     ...
# 3918      4
# 3923      1
# 3928      1
# 3937      1
# 3942      4
#
#                                                                                                                          text  \
# 0              My considerate roommate cooked some meat with a beautifully weird smell in our apartment and I almost threw up
# 5                                                         Turns out, tag between super heroes can get like a sibling rivalry.
# 10       Then as I gathered courage to go down I realized there was a fire across the street, but it seems to be in hand now.
# 15    It's absolutely fine that I got an older car for my 16th birthday, while one of my best friend who got a BRAND new BMW!
# 20                                                                                                    He was in a black mood.
# ...                                                                                                                       ...
# 3918                                                                                          The speech crowned the meeting.
# 3923              I was overjoyed when someone backed into my new SUV while driving through the parking lot the other day and
# 3928                                            I almost crashed my car because the guy that cut me off was being so careful.
# 3937                                       I was so delighted when I came home to find my dog rooting through the garbage can
# 3942                                                                                He shouldered the costs for the accident.
#
#       pred model  n_models
# 0        1  bert         5
# 5        3  bert         5
# 10       2  bert         5
# 15       1  bert         5
# 20       4  bert         5
# ...    ...   ...       ...
# 3918     4  bert         5
# 3923     1  bert         5
# 3928     1  bert         5
# 3937     1  bert         5
# 3942     4  bert         5
#
# [714 rows x 5 columns]

# %%
good_to_select_from = good_updated[good_updated['n_models'] == 5].drop_duplicates('text')

sarc_good = good_to_select_from[good_to_select_from['label'] == 1].sample(7, random_state=45)[['text', 'label', 'model']]
idiom_good = good_to_select_from[good_to_select_from['label'] == 2].sample(7, random_state=45)[['text', 'label', 'model']]
simile_good = good_to_select_from[good_to_select_from['label'] == 3].sample(7, random_state=45)[['text', 'label', 'model']]
metaphor_good = good_to_select_from[good_to_select_from['label'] == 4].sample(7, random_state=45)[['text', 'label', 'model']]

# %% [markdown]
# # 6. Write out final samples as dataframe

# %%
sample_temp = pd.concat([sarc_mis, idiom_mis, simile_mis, metaphor_mis], axis=0)
sample_temp['difficult'] = "yes"

# %%
sample_temp_2 = pd.concat([sarc_good, idiom_good, simile_good, metaphor_good], axis=0)
sample_temp_2['difficult'] = "no"

# %%
sample_final = pd.concat([sample_temp, sample_temp_2], axis=0)
sample_final = shuffle(sample_final, random_state=45)
sample_final
# Out:
#                                                                                                                                                                                     text  \
# 1598                                                                                                                                                I wanted that gift as much as cancer
# 140                                                                                              I was encouraged not to get a response back from the company after applying for the job
# 1812                                                                         I felt like a hero when I realized that I brought a present for a baby boy to a baby shower for a baby girl
# 217                                                                                                                                                         The armor was tough as glass
# 137                                                                                                                          That is why it is so important to remain like a planted oak
# 138                                                                                                           But today carly wanted to feel like a kick-ass chick in a superhero movie.
# 2503                                                                                                                                                      They were burning with desire.
# 3058                                                                                                                                             The tax cut will fertilize the economy.
# 62                                                                                                                                He spent three years seconded to a lame duck industry.
# 205                                                                                                                                                      And  made  answer very gravely.
# 69                                                                                                   I farted in the middle of my speech but no big deal; it happens to me all the time.
# 2980                                                                                                                                                     I do bear that in mind, doctor.
# 80                                                                                    Recently I ate at a restaurant and the whole place smelled terrible, just like a bouquet of roses.
# 1290                                                                                                                                                   John fell behind his class mates.
# 70                                                                                                                                           The whole family moved out bag and baggage.
# 224                                                                                         I am super proud that my 15 year old son crashed my ferrari while taking it for a test drive
# 234                                                                                                          You can freely switch between them but the rest go like a deflated dummies.
# 1433                                                                     If I could just go with the flow for a couple of hours, I may just have a decent enough time to get through it.
# 30                                                                                                                                                 You're as affectionate as a crocodile
# 84                                                                                                    He could hear the screams of her victims, could smell burnt flesh and taste blood.
# 73                                                                 Second , it would ensure that workers enjoyed positive rights under law and reduce the emphasis of union immunities .
# 2184                                                                                                                                            Her optimism flicked away these worries.
# 5                                                                                                                    Turns out, tag between super heroes can get like a sibling rivalry.
# 2651                                                                                                                        The wildfire ravaged through the forest at an amazing speed.
# 10                                                                                                                                                      The situation was cut and dried.
# 2479                                                                                                                                  It's the same with bardem, only to the nth degree.
# 202                                                                                                I was grateful not to get a response back from the company after applying for the job
# 2804                                                                           We will, gentlemen, sink or swim together on this, because we are too closely linked to do anything else.
# 2907                                                                                                                   The formula was as well-known as the eleventh president of Zambia
# 3601                                                                                       I am so excited when my wifi connection drops and becomes too slow to stream my favorite show
# 222                                                                                                                                        And rest can never dwell , hope never  comes.
# 35                                                                                                                                                             I'm going to take a leak.
# 186                                                                                                                                                  Robed  with darkness as a garment .
# 113                                                                                                                                                    The politician toppled his rival.
# 2513                                                                                                                                             The fabric was as smooth as a washboard
# 747                                                                                                                                                            Alexander's spirits rose.
# 2995                                                                                                                            I looked down at him, and he smiled at me like an angel.
# 154                                                                                                                          A thought forms in my mind and it's like a sun-filled day .
# 3073                                                You 'll be whatever you have to be to make this company run smoothly, or your name will come off that door before you can say knife!
# 102                                                                                                                                He thinks these documents will leak out soon or late.
# 386                                                The fact that I got so drunk on my birthday and said some really terrible things to one of my oldest friends makes me feel just great
# 178                                                                                                                                    fitting for the new arrival, she's full of beans.
# 2733                                                                                             It starts to worry you that everyone is like a snowman looking at the first spring sun.
# 147                                                                                                          He finds out what the needs of the business are , and prescribes the cure .
# 105                                                                                                                                            l am getting a little broad in the beam .
# 21    God, I'm beautiful even with all these freaks still clambering over my back, stitching me up with all that snake-like twine theyd used in my operation, I look like a vogue model.
# 149                                                                     I was happily waiting to find out some lab results and wasn't sure if they would diagnose me with something cute
# 188                                                                                               One day you decide to test it out and what you experience is like a fantastical dream.
# 58                                                                            There are few things in life as pleasant as almost vomiting when seeing a person eating a cockroach on TV.
# 10                                                                  Then as I gathered courage to go down I realized there was a fire across the street, but it seems to be in hand now.
# 59                                                                                                                                                            You disagree? Okay, shoot!
# 2424                                                                              I was so happy with myself when my social anxiety caused me to make a mistake while paying the cashier
# 2656                                                                                       I feel so loved when my husband works long hours and I'm by myself in the middle of the night
# 247                                                                                                         That guy who let his dog run off leash and scare my dogs needs to be praised
# 1056                                                                                      I felt overjoyed when I realized that I couldn't afford to get my daughter the gift she wanted
# 226                                                                                          day in, day out, I work hard to put food on the table, and then I cop this from the missus.
#
#       label    model difficult
# 1598      3     bert        no
# 140       1       rf       yes
# 1812      1     bert        no
# 217       3       rf       yes
# 137       3       rf       yes
# 138       3       rf       yes
# 2503      4     bert        no
# 3058      4     bert        no
# 62        2     bert       yes
# 205       4       rf       yes
# 69        1     bert       yes
# 2980      2     bert        no
# 80        1     bert       yes
# 1290      4     bert        no
# 70        2     bert       yes
# 224       1     bert        no
# 234       3       rf       yes
# 1433      2     bert        no
# 30        3     bert        no
# 84        2     bert       yes
# 73        4     bert       yes
# 2184      4     bert        no
# 5         3     bert        no
# 2651      4     bert        no
# 10        2     bert       yes
# 2479      2     bert        no
# 202       1       rf       yes
# 2804      2     bert        no
# 2907      3     bert        no
# 3601      1     bert        no
# 222       4       rf       yes
# 35        2     bert        no
# 186       4       rf       yes
# 113       4     bert        no
# 2513      3     bert        no
# 747       4     bert        no
# 2995      3     bert        no
# 154       3       rf       yes
# 3073      2     bert        no
# 102       4  roberta       yes
# 386       1     bert        no
# 178       2       rf       yes
# 2733      3     bert        no
# 147       4       rf       yes
# 105       2  roberta       yes
# 21        3     bert       yes
# 149       1       rf       yes
# 188       3       rf       yes
# 58        1     bert       yes
# 10        2     bert        no
# 59        4     bert       yes
# 2424      1     bert        no
# 2656      1     bert        no
# 247       1       lr       yes
# 1056      1     bert        no
# 226       2       rf       yes

# %%
sample_final.to_csv('../results/human_annotation/samples_to_annotate.csv')
