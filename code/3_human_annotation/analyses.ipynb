# %%
import sys, re, string, pickle
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from collections import defaultdict
from sklearn.metrics import confusion_matrix
pd.set_option('display.max_colwidth', None)

# %%
data = pd.read_csv("../results/human_annotation/prolific_results.csv", encoding='utf-8')
data = data.T
data = data.reset_index()
data = data.drop([0, 1], axis=0)
data.head(3)
# Out:
#                                                                                                        index  \
# 2                                                                       I wanted that gift as much as cancer
# 3  Which words were most indicative for your decision? (maximum 3 words or phrases, separated by commas (,))
# 4                    I was encouraged not to get a response back from the company after applying for the job
#
#                       0            1             2                   3  \
# 2               sarcasm     metaphor       sarcasm             sarcasm
# 3  wanted, gift, cancer  as much as,  cancer, gift  gift, much, cancer
# 4               sarcasm      sarcasm         idiom               idiom
#
#             4                      5           6                   7  \
# 2      simile                sarcasm     sarcasm             sarcasm
# 3  as much as  Wanted, Gift, Cancer,  as much as  cancer, that, gift
# 4     sarcasm                  idiom       idiom              simile
#
#                  8             9                    10                    11  \
# 2          sarcasm       sarcasm               sarcasm               sarcasm
# 3  as much cancer,  cancer, want  gift, wanted, cancer  wanted, gift, cancer
# 4            idiom         idiom               sarcasm               sarcasm
#
#                    12                     13           14
# 2             sarcasm                sarcasm      sarcasm
# 3  gift, much, cancer  wanted, gift, cancer,  gift cancer
# 4               idiom                sarcasm        idiom

# %% [markdown]
# # 1. Get labels and reason words

# %% [markdown]
# ## 1.1 Labels assigned by human participants

# %%
classification = data.iloc[::2]
classification = classification.reset_index(drop=True)
classification = classification.add_prefix('part_')
classification = classification.rename(columns={"part_index":"text"})
classification.head(3)
# Out:
#                                                                                                           text  \
# 0                                                                         I wanted that gift as much as cancer
# 1                      I was encouraged not to get a response back from the company after applying for the job
# 2  I felt like a hero when I realized that I brought a present for a baby boy to a baby shower for a baby girl
#
#     part_0    part_1   part_2   part_3   part_4   part_5    part_6   part_7  \
# 0  sarcasm  metaphor  sarcasm  sarcasm   simile  sarcasm   sarcasm  sarcasm
# 1  sarcasm   sarcasm    idiom    idiom  sarcasm    idiom     idiom   simile
# 2  sarcasm     idiom   simile  sarcasm  sarcasm   simile  metaphor    idiom
#
#     part_8   part_9  part_10  part_11  part_12  part_13  part_14
# 0  sarcasm  sarcasm  sarcasm  sarcasm  sarcasm  sarcasm  sarcasm
# 1    idiom    idiom  sarcasm  sarcasm    idiom  sarcasm    idiom
# 2   simile  sarcasm  sarcasm  sarcasm  sarcasm   simile  sarcasm

# %% [markdown]
# ## 1.2 Reason words named by participants

# %%
reasons = data.iloc[1::2]
reasons = reasons.drop('index', axis=1)
reasons = reasons.reset_index(drop=True)
reasons = reasons.add_prefix('keyword_')
reasons = reasons.rename(columns={"keyword_index":"text"})
reasons.head(3)
# Out:
#                   keyword_0          keyword_1              keyword_2  \
# 0      wanted, gift, cancer        as much as,           cancer, gift
# 1  encouraged, not response  no, get, applying  was encouraged not to
# 2                felt, hero  felt like a hero,       felt like a hero
#
#                                      keyword_3   keyword_4  \
# 0                           gift, much, cancer  as much as
# 1    not get a response back, from the company         not
# 2  hero, baby boy, to a baby shower for a girl         for
#
#                keyword_5    keyword_6                    keyword_7  \
# 0  Wanted, Gift, Cancer,   as much as           cancer, that, gift
# 1            not to get,   not to get  encouraged, response, after
# 2           like a hero,  I felt like          when, brought, baby
#
#              keyword_8         keyword_9            keyword_10  \
# 0      as much cancer,      cancer, want  gift, wanted, cancer
# 1  encouraged not to,   not get response    not, response, job
# 2         felt like a,   hero, boy, girl       hero, boy, girl
#
#                   keyword_11                  keyword_12  \
# 0       wanted, gift, cancer          gift, much, cancer
# 1  encouraged, not, response  not to get a response back
# 2  hero, baby boy, baby girl            hero, baby, girl
#
#                         keyword_13        keyword_14
# 0            wanted, gift, cancer,       gift cancer
# 1  encouraged, response, applying,  not get response
# 2              Hero, present, boy,              hero

# %% [markdown]
# ## 1.3 Concatenate dataframes

# %%
conc = pd.concat([classification, reasons], axis=1)
conc.head(3)
# Out:
#                                                                                                           text  \
# 0                                                                         I wanted that gift as much as cancer
# 1                      I was encouraged not to get a response back from the company after applying for the job
# 2  I felt like a hero when I realized that I brought a present for a baby boy to a baby shower for a baby girl
#
#     part_0    part_1   part_2   part_3   part_4   part_5    part_6   part_7  \
# 0  sarcasm  metaphor  sarcasm  sarcasm   simile  sarcasm   sarcasm  sarcasm
# 1  sarcasm   sarcasm    idiom    idiom  sarcasm    idiom     idiom   simile
# 2  sarcasm     idiom   simile  sarcasm  sarcasm   simile  metaphor    idiom
#
#     part_8  ...              keyword_5    keyword_6  \
# 0  sarcasm  ...  Wanted, Gift, Cancer,   as much as
# 1    idiom  ...            not to get,   not to get
# 2   simile  ...           like a hero,  I felt like
#
#                      keyword_7            keyword_8         keyword_9  \
# 0           cancer, that, gift      as much cancer,      cancer, want
# 1  encouraged, response, after  encouraged not to,   not get response
# 2          when, brought, baby         felt like a,   hero, boy, girl
#
#              keyword_10                 keyword_11  \
# 0  gift, wanted, cancer       wanted, gift, cancer
# 1    not, response, job  encouraged, not, response
# 2       hero, boy, girl  hero, baby boy, baby girl
#
#                    keyword_12                       keyword_13  \
# 0          gift, much, cancer            wanted, gift, cancer,
# 1  not to get a response back  encouraged, response, applying,
# 2            hero, baby, girl              Hero, present, boy,
#
#          keyword_14
# 0       gift cancer
# 1  not get response
# 2              hero
#
# [3 rows x 31 columns]

# %%
source = pd.read_csv('../results/human_annotation/samples_to_annotate.csv')
final = source.merge(conc, left_on='text', right_on='text')

num_to_label = {1: "sarcasm", 2: "idiom", 3: "simile", 4: "metaphor"}
label_to_num = {"sarcasm":1, "idiom":2, "simile":3, "metaphor":4}

final['label'] = final['label'].map(num_to_label)

# %%
for i, row in classification.iterrows():
    sarc = 0
    idiom = 0
    metaphor = 0
    simile = 0
    
    for j in range(1, 16):
        if row[j] == "sarcasm":
            sarc +=1
        if row[j] == "idiom":
            idiom +=1
        if row[j] == "metaphor":
            metaphor +=1
        if row[j] == "simile":
            simile +=1
    rowdict = {"sarcasm": sarc, "idiom": idiom, "metaphor":metaphor, "simile": simile}
    max_value = max(sarc, idiom, metaphor, simile)

    if max_value <7:
        print(max_value)
    # rowdict_rev = {v:k for k, v in rowdict.items()}
    rowdict_rev = defaultdict(list)
    for k, v in rowdict.items():
        rowdict_rev[v].append(k)

    if max_value >= 7:
        classification.loc[i, 'agreement'] = 'high'
        classification.loc[i, 'majority'] = str(rowdict_rev[max_value])
    
    #comment out for alternative statistics
    else:
        classification.loc[i, 'agreement'] = 'low'
        classification.loc[i, 'majority'] = str(rowdict_rev[max_value])
# Out:
# 6
# 6
# 6
# 6

# %%
conc = pd.concat([classification, reasons], axis=1)
final = source.merge(conc, left_on='text', right_on='text')

num_to_label = {1: "sarcasm", 2: "idiom", 3: "simile", 4: "metaphor"}
label_to_num = {"sarcasm":1, "idiom":2, "simile":3, "metaphor":4}

final['label'] = final['label'].map(num_to_label)
final.head()
# Out:
#    Unnamed: 0  \
# 0        1598
# 1         140
# 2        1812
# 3         217
# 4         137
#
#                                                                                                           text  \
# 0                                                                         I wanted that gift as much as cancer
# 1                      I was encouraged not to get a response back from the company after applying for the job
# 2  I felt like a hero when I realized that I brought a present for a baby boy to a baby shower for a baby girl
# 3                                                                                 The armor was tough as glass
# 4                                                  That is why it is so important to remain like a planted oak
#
#      label model difficult   part_0    part_1    part_2    part_3   part_4  \
# 0   simile  bert        no  sarcasm  metaphor   sarcasm   sarcasm   simile
# 1  sarcasm    rf       yes  sarcasm   sarcasm     idiom     idiom  sarcasm
# 2  sarcasm  bert        no  sarcasm     idiom    simile   sarcasm  sarcasm
# 3   simile    rf       yes  sarcasm  metaphor  metaphor   sarcasm   simile
# 4   simile    rf       yes   simile     idiom    simile  metaphor    idiom
#
#    ...              keyword_5     keyword_6                    keyword_7  \
# 0  ...  Wanted, Gift, Cancer,    as much as           cancer, that, gift
# 1  ...            not to get,    not to get  encouraged, response, after
# 2  ...           like a hero,   I felt like          when, brought, baby
# 3  ...    armor, tough, glass  was tough as          armor, tough, glass
# 4  ...     like, planted oak,        like a            remain, like, oak
#
#              keyword_8            keyword_9            keyword_10  \
# 0      as much cancer,         cancer, want  gift, wanted, cancer
# 1  encouraged not to,      not get response    not, response, job
# 2         felt like a,      hero, boy, girl       hero, boy, girl
# 3      tough as, glass        armour, glass      tough, as, glass
# 4   to remain, like a,  remain, planted oak    like, planted, oak
#
#                   keyword_11                  keyword_12  \
# 0       wanted, gift, cancer          gift, much, cancer
# 1  encouraged, not, response  not to get a response back
# 2  hero, baby boy, baby girl            hero, baby, girl
# 3             was, tough, as        armor, tough, glass,
# 4        remain, planted oak         like a planted oak,
#
#                         keyword_13        keyword_14
# 0            wanted, gift, cancer,       gift cancer
# 1  encouraged, response, applying,  not get response
# 2              Hero, present, boy,              hero
# 3             Armor, tough, glass,    tough as glass
# 4         important, planted, oak,              like
#
# [5 rows x 37 columns]

# %% [markdown]
# # 2. Get majority labels, easy instances and difficult instances

# %%
final['majority'] = final['majority'].str.replace("[", "", regex=True)
final['majority'] = final['majority'].str.replace("]", "", regex=True)
final['majority'] = final['majority'].str.replace("'", "", regex=True)
final = final.dropna()

# %%
easy = final[final['difficult'] == "no"]
hard = final[final['difficult'] == "yes"]

# %%
final[final['majority'] != final['label']][['label', 'majority']].value_counts('label')
# Out:
# label
# metaphor    9
# simile      5
# idiom       3
# sarcasm     1
# dtype: int64

# %%
easy[easy['majority'] != easy['label']][['label', 'majority']].value_counts('label')
# Out:
# label
# metaphor    3
# simile      3
# idiom       1
# dtype: int64

# %%
hard[hard['majority'] != hard['label']][['label', 'majority']].value_counts('label')
# Out:
# label
# metaphor    6
# idiom       2
# simile      2
# sarcasm     1
# dtype: int64

# %%
hard[['text', 'label', 'majority', 'model']]
# Out:
#                                                                                                                                                                                   text  \
# 1                                                                                              I was encouraged not to get a response back from the company after applying for the job
# 3                                                                                                                                                         The armor was tough as glass
# 4                                                                                                                          That is why it is so important to remain like a planted oak
# 5                                                                                                           But today carly wanted to feel like a kick-ass chick in a superhero movie.
# 8                                                                                                                               He spent three years seconded to a lame duck industry.
# 9                                                                                                                                                      And  made  answer very gravely.
# 10                                                                                                 I farted in the middle of my speech but no big deal; it happens to me all the time.
# 12                                                                                  Recently I ate at a restaurant and the whole place smelled terrible, just like a bouquet of roses.
# 14                                                                                                                                         The whole family moved out bag and baggage.
# 16                                                                                                         You can freely switch between them but the rest go like a deflated dummies.
# 19                                                                                                  He could hear the screams of her victims, could smell burnt flesh and taste blood.
# 20                                                               Second , it would ensure that workers enjoyed positive rights under law and reduce the emphasis of union immunities .
# 24                                                                                                                                                    The situation was cut and dried.
# 26                                                                                               I was grateful not to get a response back from the company after applying for the job
# 30                                                                                                                                       And rest can never dwell , hope never  comes.
# 32                                                                                                                                                 Robed  with darkness as a garment .
# 37                                                                                                                         A thought forms in my mind and it's like a sun-filled day .
# 39                                                                                                                               He thinks these documents will leak out soon or late.
# 41                                                                                                                                   fitting for the new arrival, she's full of beans.
# 43                                                                                                         He finds out what the needs of the business are , and prescribes the cure .
# 44                                                                                                                                           l am getting a little broad in the beam .
# 45  God, I'm beautiful even with all these freaks still clambering over my back, stitching me up with all that snake-like twine theyd used in my operation, I look like a vogue model.
# 46                                                                    I was happily waiting to find out some lab results and wasn't sure if they would diagnose me with something cute
# 47                                                                                              One day you decide to test it out and what you experience is like a fantastical dream.
# 48                                                                          There are few things in life as pleasant as almost vomiting when seeing a person eating a cockroach on TV.
# 50                                                                                                                                                          You disagree? Okay, shoot!
# 53                                                                                                        That guy who let his dog run off leash and scare my dogs needs to be praised
# 55                                                                                         day in, day out, I work hard to put food on the table, and then I cop this from the missus.
#
#        label  majority    model
# 1    sarcasm     idiom       rf
# 3     simile  metaphor       rf
# 4     simile    simile       rf
# 5     simile    simile       rf
# 8      idiom     idiom     bert
# 9   metaphor     idiom       rf
# 10   sarcasm   sarcasm     bert
# 12   sarcasm   sarcasm     bert
# 14     idiom     idiom     bert
# 16    simile    simile       rf
# 19     idiom  metaphor     bert
# 20  metaphor     idiom     bert
# 24     idiom     idiom     bert
# 26   sarcasm   sarcasm       rf
# 30  metaphor     idiom       rf
# 32  metaphor  metaphor       rf
# 37    simile    simile       rf
# 39  metaphor     idiom  roberta
# 41     idiom  metaphor       rf
# 43  metaphor     idiom       rf
# 44     idiom     idiom  roberta
# 45    simile   sarcasm     bert
# 46   sarcasm   sarcasm       rf
# 47    simile    simile       rf
# 48   sarcasm   sarcasm     bert
# 50  metaphor     idiom     bert
# 53   sarcasm   sarcasm       lr
# 55     idiom     idiom       rf

# %%
easy[['text', 'label', 'majority']]
# Out:
#                                                                                                                                      text  \
# 0                                                                                                    I wanted that gift as much as cancer
# 2                             I felt like a hero when I realized that I brought a present for a baby boy to a baby shower for a baby girl
# 6                                                                                                          They were burning with desire.
# 7                                                                                                 The tax cut will fertilize the economy.
# 11                                                                                                        I do bear that in mind, doctor.
# 13                                                                                                      John fell behind his class mates.
# 15                                           I am super proud that my 15 year old son crashed my ferrari while taking it for a test drive
# 17                        If I could just go with the flow for a couple of hours, I may just have a decent enough time to get through it.
# 18                                                                                                  You're as affectionate as a crocodile
# 21                                                                                               Her optimism flicked away these worries.
# 22                                                                    Turns out, tag between super heroes can get like a sibling rivalry.
# 23                                                                           The wildfire ravaged through the forest at an amazing speed.
# 25                                                                                     It's the same with bardem, only to the nth degree.
# 27                              We will, gentlemen, sink or swim together on this, because we are too closely linked to do anything else.
# 28                                                                      The formula was as well-known as the eleventh president of Zambia
# 29                                          I am so excited when my wifi connection drops and becomes too slow to stream my favorite show
# 31                                                                                                              I'm going to take a leak.
# 33                                                                                                      The politician toppled his rival.
# 34                                                                                                The fabric was as smooth as a washboard
# 35                                                                                                              Alexander's spirits rose.
# 36                                                                               I looked down at him, and he smiled at me like an angel.
# 38   You 'll be whatever you have to be to make this company run smoothly, or your name will come off that door before you can say knife!
# 40  The fact that I got so drunk on my birthday and said some really terrible things to one of my oldest friends makes me feel just great
# 42                                                It starts to worry you that everyone is like a snowman looking at the first spring sun.
# 49                   Then as I gathered courage to go down I realized there was a fire across the street, but it seems to be in hand now.
# 51                                 I was so happy with myself when my social anxiety caused me to make a mistake while paying the cashier
# 52                                          I feel so loved when my husband works long hours and I'm by myself in the middle of the night
# 54                                         I felt overjoyed when I realized that I couldn't afford to get my daughter the gift she wanted
#
#        label  majority
# 0     simile   sarcasm
# 2    sarcasm   sarcasm
# 6   metaphor  metaphor
# 7   metaphor  metaphor
# 11     idiom     idiom
# 13  metaphor     idiom
# 15   sarcasm   sarcasm
# 17     idiom     idiom
# 18    simile   sarcasm
# 21  metaphor  metaphor
# 22    simile    simile
# 23  metaphor     idiom
# 25     idiom     idiom
# 27     idiom     idiom
# 28    simile   sarcasm
# 29   sarcasm   sarcasm
# 31     idiom  metaphor
# 33  metaphor  metaphor
# 34    simile    simile
# 35  metaphor     idiom
# 36    simile    simile
# 38     idiom     idiom
# 40   sarcasm   sarcasm
# 42    simile    simile
# 49     idiom     idiom
# 51   sarcasm   sarcasm
# 52   sarcasm   sarcasm
# 54   sarcasm   sarcasm

# %% [markdown]
# # 3. Plot confusion matrix of human annotations

# %%
cm = confusion_matrix(hard['label'], hard['majority'], normalize = 'true', 
                      labels=['sarcasm', 'simile', 'idiom', 'metaphor'])
figure = sns.heatmap(cm, annot=True, cmap="GnBu", fmt=".2f", xticklabels = ['sarcasm', 'simile', 'idiom', 'metaphor'], 
                  yticklabels=['sarcasm', 'simile', 'idiom', 'metaphor'])
plt.savefig('../results/human_annotation/heatmap_hard.pdf')
plt.close()

# %%
cm = confusion_matrix(easy['label'], easy['majority'], normalize = 'true', 
                      labels=['sarcasm', 'simile', 'idiom', 'metaphor'])
figure = sns.heatmap(cm, annot=True, cmap="GnBu", fmt=".2f", xticklabels = ['sarcasm', 'simile', 'idiom', 'metaphor'], 
                  yticklabels=['sarcasm', 'simile', 'idiom', 'metaphor'])
plt.savefig('../results/human_annotation/heatmap_easy.pdf')
plt.close()

# %% [markdown]
# # 4. Write out reason words

# %%
def get_words(df):
    
    all_results = []
    for i, row in df.iterrows():
        try:
            all_word_per_row = " ".join(row).lower()
        except TypeError:
            all_word_per_row = "error"
            
        all_word_per_row = all_word_per_row.translate(str.maketrans('', '', string.punctuation))
        words = all_word_per_row.strip().split()
        mydict = defaultdict(int)
        for token in words:
            mydict[token] +=1
        mydict = {k: v for k, v in sorted(mydict.items(), key=lambda item: item[1], reverse=True)}
        all_results.append(mydict)

    return all_results

# %%
final[['keyword_0', 'keyword_1']].head(5)
# Out:
#                   keyword_0          keyword_1
# 0      wanted, gift, cancer        as much as,
# 1  encouraged, not response  no, get, applying
# 2                felt, hero  felt like a hero,
# 3       armor, tough, glass   tough, as, glass
# 4         like, planted oak       planted oak,

# %%
final['all_words'] = get_words(final.iloc[:, 22:])

# %%
final[['text', 'label', 'majority', 'all_words']]
# Out:
#                                                                                                                                                                                   text  \
# 0                                                                                                                                                 I wanted that gift as much as cancer
# 1                                                                                              I was encouraged not to get a response back from the company after applying for the job
# 2                                                                          I felt like a hero when I realized that I brought a present for a baby boy to a baby shower for a baby girl
# 3                                                                                                                                                         The armor was tough as glass
# 4                                                                                                                          That is why it is so important to remain like a planted oak
# 5                                                                                                           But today carly wanted to feel like a kick-ass chick in a superhero movie.
# 6                                                                                                                                                       They were burning with desire.
# 7                                                                                                                                              The tax cut will fertilize the economy.
# 8                                                                                                                               He spent three years seconded to a lame duck industry.
# 9                                                                                                                                                      And  made  answer very gravely.
# 10                                                                                                 I farted in the middle of my speech but no big deal; it happens to me all the time.
# 11                                                                                                                                                     I do bear that in mind, doctor.
# 12                                                                                  Recently I ate at a restaurant and the whole place smelled terrible, just like a bouquet of roses.
# 13                                                                                                                                                   John fell behind his class mates.
# 14                                                                                                                                         The whole family moved out bag and baggage.
# 15                                                                                        I am super proud that my 15 year old son crashed my ferrari while taking it for a test drive
# 16                                                                                                         You can freely switch between them but the rest go like a deflated dummies.
# 17                                                                     If I could just go with the flow for a couple of hours, I may just have a decent enough time to get through it.
# 18                                                                                                                                               You're as affectionate as a crocodile
# 19                                                                                                  He could hear the screams of her victims, could smell burnt flesh and taste blood.
# 20                                                               Second , it would ensure that workers enjoyed positive rights under law and reduce the emphasis of union immunities .
# 21                                                                                                                                            Her optimism flicked away these worries.
# 22                                                                                                                 Turns out, tag between super heroes can get like a sibling rivalry.
# 23                                                                                                                        The wildfire ravaged through the forest at an amazing speed.
# 24                                                                                                                                                    The situation was cut and dried.
# 25                                                                                                                                  It's the same with bardem, only to the nth degree.
# 26                                                                                               I was grateful not to get a response back from the company after applying for the job
# 27                                                                           We will, gentlemen, sink or swim together on this, because we are too closely linked to do anything else.
# 28                                                                                                                   The formula was as well-known as the eleventh president of Zambia
# 29                                                                                       I am so excited when my wifi connection drops and becomes too slow to stream my favorite show
# 30                                                                                                                                       And rest can never dwell , hope never  comes.
# 31                                                                                                                                                           I'm going to take a leak.
# 32                                                                                                                                                 Robed  with darkness as a garment .
# 33                                                                                                                                                   The politician toppled his rival.
# 34                                                                                                                                             The fabric was as smooth as a washboard
# 35                                                                                                                                                           Alexander's spirits rose.
# 36                                                                                                                            I looked down at him, and he smiled at me like an angel.
# 37                                                                                                                         A thought forms in my mind and it's like a sun-filled day .
# 38                                                You 'll be whatever you have to be to make this company run smoothly, or your name will come off that door before you can say knife!
# 39                                                                                                                               He thinks these documents will leak out soon or late.
# 40                                               The fact that I got so drunk on my birthday and said some really terrible things to one of my oldest friends makes me feel just great
# 41                                                                                                                                   fitting for the new arrival, she's full of beans.
# 42                                                                                             It starts to worry you that everyone is like a snowman looking at the first spring sun.
# 43                                                                                                         He finds out what the needs of the business are , and prescribes the cure .
# 44                                                                                                                                           l am getting a little broad in the beam .
# 45  God, I'm beautiful even with all these freaks still clambering over my back, stitching me up with all that snake-like twine theyd used in my operation, I look like a vogue model.
# 46                                                                    I was happily waiting to find out some lab results and wasn't sure if they would diagnose me with something cute
# 47                                                                                              One day you decide to test it out and what you experience is like a fantastical dream.
# 48                                                                          There are few things in life as pleasant as almost vomiting when seeing a person eating a cockroach on TV.
# 49                                                                Then as I gathered courage to go down I realized there was a fire across the street, but it seems to be in hand now.
# 50                                                                                                                                                          You disagree? Okay, shoot!
# 51                                                                              I was so happy with myself when my social anxiety caused me to make a mistake while paying the cashier
# 52                                                                                       I feel so loved when my husband works long hours and I'm by myself in the middle of the night
# 53                                                                                                        That guy who let his dog run off leash and scare my dogs needs to be praised
# 54                                                                                      I felt overjoyed when I realized that I couldn't afford to get my daughter the gift she wanted
# 55                                                                                         day in, day out, I work hard to put food on the table, and then I cop this from the missus.
#
#        label  majority  \
# 0     simile   sarcasm
# 1    sarcasm     idiom
# 2    sarcasm   sarcasm
# 3     simile  metaphor
# 4     simile    simile
# 5     simile    simile
# 6   metaphor  metaphor
# 7   metaphor  metaphor
# 8      idiom     idiom
# 9   metaphor     idiom
# 10   sarcasm   sarcasm
# 11     idiom     idiom
# 12   sarcasm   sarcasm
# 13  metaphor     idiom
# 14     idiom     idiom
# 15   sarcasm   sarcasm
# 16    simile    simile
# 17     idiom     idiom
# 18    simile   sarcasm
# 19     idiom  metaphor
# 20  metaphor     idiom
# 21  metaphor  metaphor
# 22    simile    simile
# 23  metaphor     idiom
# 24     idiom     idiom
# 25     idiom     idiom
# 26   sarcasm   sarcasm
# 27     idiom     idiom
# 28    simile   sarcasm
# 29   sarcasm   sarcasm
# 30  metaphor     idiom
# 31     idiom  metaphor
# 32  metaphor  metaphor
# 33  metaphor  metaphor
# 34    simile    simile
# 35  metaphor     idiom
# 36    simile    simile
# 37    simile    simile
# 38     idiom     idiom
# 39  metaphor     idiom
# 40   sarcasm   sarcasm
# 41     idiom  metaphor
# 42    simile    simile
# 43  metaphor     idiom
# 44     idiom     idiom
# 45    simile   sarcasm
# 46   sarcasm   sarcasm
# 47    simile    simile
# 48   sarcasm   sarcasm
# 49     idiom     idiom
# 50  metaphor     idiom
# 51   sarcasm   sarcasm
# 52   sarcasm   sarcasm
# 53   sarcasm   sarcasm
# 54   sarcasm   sarcasm
# 55     idiom     idiom
#
#                                                                                                                                                                                                                                                                                                          all_words
# 0                                                                                                                                                                                                                                {'cancer': 12, 'gift': 10, 'as': 7, 'much': 6, 'wanted': 5, 'that': 1, 'want': 1}
# 1                                                                                                                                     {'not': 12, 'response': 9, 'get': 7, 'encouraged': 6, 'to': 5, 'applying': 2, 'a': 2, 'back': 2, 'no': 1, 'was': 1, 'from': 1, 'the': 1, 'company': 1, 'after': 1, 'job': 1}
# 2                                                                                                                                                        {'hero': 11, 'a': 6, 'baby': 6, 'felt': 5, 'like': 5, 'boy': 5, 'girl': 5, 'for': 2, 'to': 1, 'shower': 1, 'i': 1, 'when': 1, 'brought': 1, 'present': 1}
# 3                                                                                                                                                                                                                                           {'tough': 13, 'glass': 12, 'as': 8, 'armor': 5, 'armour': 2, 'was': 2}
# 4                                                                                                                                                                                                                             {'oak': 11, 'like': 10, 'planted': 10, 'remain': 6, 'a': 5, 'to': 1, 'important': 1}
# 5                                                                                                                                                                         {'like': 9, 'kickass': 7, 'superhero': 7, 'feel': 5, 'a': 5, 'chick': 4, 'movie': 2, 'kick': 2, 'ass': 2, 'wanted': 2, 'in': 1, 'to': 1}
# 6                                                                                                                                                                                                                                                 {'burning': 13, 'desire': 12, 'with': 8, 'were': 2, 'buring': 1}
# 7                                                                                                                                                                                               {'fertilize': 12, 'economy': 8, 'tax': 4, 'the': 2, 'cut': 2, 'ferilize': 1, 'fertilise': 1, 'with': 1, 'will': 1}
# 8                                                                                                                                                                                                   {'duck': 14, 'lame': 13, 'industry': 8, 'seconded': 2, 'industy': 1, 'three': 1, 'to': 1, 'he': 1, 'spent': 1}
# 9                                                                                                                                                                                                                                                               {'gravely': 13, 'very': 6, 'answer': 6, 'made': 4}
# 10                                                                                                                                            {'no': 11, 'deal': 10, 'big': 8, 'happens': 7, 'all': 5, 'time': 5, 'farted': 5, 'the': 4, 'to': 2, 'me': 2, 'biog': 1, 'it': 1, 'middle': 1, 'but': 1, 'speech': 1}
# 11                                                                                                                                                                                                                                       {'bear': 11, 'mind': 9, 'do': 5, 'doctor': 5, 'that': 3, 'in': 3, 'i': 2}
# 12                                                                                                                                                                                                     {'roses': 12, 'terrible': 7, 'like': 7, 'smelled': 6, 'a': 5, 'bouquet': 4, 'of': 3, 'just': 3, 'smelt': 2}
# 13                                                                                                                                                                                                                                                   {'fell': 14, 'behind': 11, 'mates': 6, 'class': 5, 'john': 1}
# 14                                                                                                                                                                                                                             {'bag': 13, 'baggage': 12, 'and': 8, 'moved': 6, 'out': 3, 'family': 2, 'whole': 1}
# 15                                                                                                                                                            {'crashed': 12, 'proud': 11, 'super': 7, 'ferrari': 5, 'my': 2, 'crased': 1, 'taking': 1, 'test': 1, 'son': 1, 'ferarri': 1, 'crash': 1, 'drive': 1}
# 16                                                                                                                                                                                                               {'dummies': 13, 'deflated': 10, 'like': 9, 'a': 3, 'go': 2, 'them': 1, 'rest': 1, 'deflatted': 1}
# 17                                                                                                             {'flow': 11, 'go': 9, 'with': 8, 'the': 5, 'get': 4, 'decent': 3, 'enough': 3, 'time': 3, 'through': 3, 'it': 3, 'if': 2, 'i': 2, 'could': 1, 'couple': 1, 'have': 1, 'may': 1, 'just': 1, 'to': 1}
# 18                                                                                                                                                                                                                                                          {'crocodile': 13, 'affectionate': 12, 'as': 8, 'a': 4}
# 19                                                                                                                                                                 {'smell': 11, 'taste': 9, 'burnt': 6, 'hear': 6, 'blood': 5, 'flesh': 5, 'could': 3, 'screams': 3, 'the': 2, 'of': 1, 'victims': 1, 'flash': 1}
# 20                                                                                                                                               {'union': 5, 'immunities': 5, 'positive': 5, 'ensure': 5, 'rights': 4, 'emphasis': 4, 'reduce': 3, 'second': 2, 'enjoyed': 2, 'under': 1, 'law': 1, 'workers': 1}
# 21                                                                                                                                                                                                                       {'flicked': 12, 'away': 7, 'optimism': 7, 'worries': 3, 'her': 1, 'these': 1, 'flick': 1}
# 22                                                                                                                                  {'like': 10, 'sibling': 8, 'rivalry': 7, 'heroes': 4, 'a': 4, 'super': 3, 'tag': 3, 'between': 2, 'can': 2, 'get': 2, 'suoer': 1, 'superheroes': 1, 'betwwen': 1, 'rivaly': 1}
# 23                                                                                                                                                                                      {'ravaged': 11, 'speed': 9, 'amazing': 8, 'wildfire': 4, 'through': 3, 'forest': 2, 'at': 1, 'an': 1, 'the': 1, 'fire': 1}
# 24                                                                                                                                                                                                                                          {'cut': 14, 'dried': 12, 'situation': 7, 'and': 6, 'was': 2, 'dry': 2}
# 25                                                                                                                                                                                                                      {'nth': 14, 'degree': 12, 'to': 4, 'the': 4, 'with': 3, 'only': 3, 'bardem': 3, 'same': 2}
# 26                                                                                                                                       {'grateful': 14, 'not': 11, 'response': 9, 'to': 6, 'get': 6, 'a': 6, 'applying': 5, 'job': 4, 'after': 3, 'the': 3, 'was': 2, 'from': 2, 'for': 2, 'company': 1, 'i': 1}
# 27                                                                                                                                                                     {'sink': 15, 'swim': 14, 'or': 11, 'together': 2, 'too': 2, 'we': 1, 'are': 1, 'closely': 1, 'linked': 1, 'because': 1, 'on': 1, 'this': 1}
# 28                                                                                                                                              {'as': 11, 'president': 7, 'well': 5, 'known': 5, 'eleventh': 5, 'zambia': 5, 'of': 4, 'wellknown': 4, 'was': 2, 'the': 2, 'formula': 2, 'wellknow': 1, '11th': 1}
# 29                                                                                                                                                                                   {'excited': 12, 'drops': 11, 'slow': 7, 'connection': 6, 'wifi': 5, 'too': 5, 'so': 2, 'favorite': 1, 'exited': 1, 'when': 1}
# 30                                                                                                                                                                                                                             {'never': 13, 'dwell': 11, 'rest': 8, 'hope': 5, 'can': 4, 'comes': 3, 'dwelll': 1}
# 31                                                                                                                                                                                                                                                           {'leak': 15, 'take': 10, 'a': 8, 'going': 1, 'im': 1}
# 32                                                                                                                                                                                                                                          {'darkness': 12, 'garment': 9, 'as': 7, 'a': 6, 'robed': 5, 'with': 3}
# 33                                                                                                                                                                                                                                                          {'toppled': 15, 'rival': 8, 'politician': 4, 'his': 3}
# 34                                                                                                                                                                                                                          {'as': 17, 'smooth': 14, 'washboard': 9, 'a': 5, 'was': 1, 'wasboard': 1, 'fabric': 1}
# 35                                                                                                                                                                                                                                                       {'rose': 15, 'spirits': 12, 'alexanders': 2, 'spirit': 1}
# 36                                                                                                                                                                                                               {'like': 12, 'an': 11, 'angel': 11, 'smiled': 4, 'me': 2, 'at': 1, 'a': 1, 'and': 1, 'looked': 1}
# 37                                                                                                                                                                                  {'like': 11, 'day': 10, 'a': 9, 'sunfilled': 8, 'its': 3, 'thought': 2, 'sun': 2, 'filled': 2, 'lika': 1, 'my': 1, 'forms': 1}
# 38                                                        {'knife': 7, 'you': 6, 'say': 6, 'before': 5, 'off': 4, 'run': 4, 'can': 4, 'name': 3, 'door': 3, 'make': 3, 'will': 2, 'come': 2, 'that': 2, 'company': 2, 'smoothly': 2, 'smooth': 1, 'or': 1, 'your': 1, 'this': 1, 'whatever': 1, 'be': 1, 'the': 1}
# 39                                                                                                                                                                   {'leak': 10, 'out': 6, 'soon': 5, 'late': 4, 'or': 3, 'documents': 3, 'sooner': 2, 'later': 2, 'thinks': 1, 'that': 1, 'will': 1, 'these': 1}
# 40                                                                                                                {'great': 13, 'terrible': 11, 'feel': 9, 'just': 7, 'things': 5, 'makes': 3, 'me': 3, 'really': 3, 'oldest': 3, 'said': 2, 'some': 2, 'friends': 2, 'thing': 1, 'so': 1, 'friend': 1, 'fact': 1}
# 41                                                                                                                                                                                                                                              {'full': 15, 'beans': 14, 'of': 11, 'new': 2, 'shes': 1, 'she': 1}
# 42                                                                                                                                                                                     {'snowman': 13, 'like': 9, 'a': 6, 'spring': 5, 'sun': 4, 'looking': 3, 'first': 3, 'at': 2, 'the': 2, 'worry': 1, 'is': 1}
# 43                                                                                                                                                                                          {'cure': 13, 'prescribes': 12, 'the': 12, 'needs': 5, 'business': 4, 'of': 3, 'presribes': 1, 'out': 1, 'buisness': 1}
# 44                                                                                                                                                                                                                        {'broad': 14, 'beam': 14, 'in': 8, 'the': 8, 'getting': 1, 'i': 1, 'am': 1, 'little': 1}
# 45  {'beautiful': 6, 'like': 5, 'model': 5, 'look': 4, 'a': 4, 'snakelike': 4, 'twine': 3, 'vogue': 3, 'stitching': 3, 'snake': 2, 'even': 2, 'god': 2, 'over': 2, 'operation': 2, 'freaks': 2, 'with': 1, 'all': 1, 'these': 1, 'freak': 1, 'clambering': 1, 'stiching': 1, 'up': 1, 'i': 1, 'vouge': 1, 'im': 1}
# 46                                                                                                                              {'lab': 9, 'cute': 9, 'results': 8, 'waiting': 6, 'happily': 5, 'diagnose': 5, 'find': 3, 'with': 3, 'something': 3, 'to': 2, 'out': 2, 'wasnt': 1, 'sure': 1, 'some': 1, 'me': 1}
# 47                                                                                                                                                                                                {'dream': 11, 'like': 10, 'fantastical': 10, 'a': 5, 'experience': 2, 'you': 2, 'decide': 1, 'what': 1, 'is': 1}
# 48                                                                                                                                                                                              {'pleasant': 14, 'vomiting': 12, 'as': 8, 'cockroach': 5, 'almost': 2, 'eating': 1, 'a': 1, 'seeing': 1, 'eat': 1}
# 49                                                                                                                    {'hand': 12, 'in': 10, 'be': 5, 'now': 5, 'to': 4, 'courage': 3, 'seems': 3, 'gathered': 3, 'go': 2, 'fire': 2, 'down': 1, 'across': 1, 'the': 1, 'street': 1, 'nowc': 1, 'but': 1, 'it': 1}
# 50                                                                                                                                                                                                                                                               {'shoot': 14, 'okay': 6, 'disagree': 5, 'you': 2}
# 51                                                                                                                                           {'happy': 11, 'mistake': 10, 'anxiety': 8, 'social': 4, 'with': 3, 'myself': 3, 'my': 2, 'make': 2, 'a': 2, 'so': 2, 'haap': 1, 'cashier': 1, 'when': 1, 'caused': 1}
# 52                                                                                                                                       {'myself': 12, 'loved': 10, 'by': 9, 'so': 6, 'long': 5, 'feel': 3, 'works': 2, 'hours': 2, 'alone': 1, 'when': 1, 'my': 1, 'husband': 1, 'im': 1, 'night': 1, 'love': 1}
# 53                                                                                                                                {'praised': 13, 'scare': 9, 'dogs': 5, 'run': 4, 'dog': 4, 'off': 3, 'my': 3, 'leash': 2, 'needs': 2, 'to': 2, 'be': 2, 'let': 2, 'his': 2, 'praise': 1, 'lets': 1, 'scared': 1}
# 54                                                                                                                                                                                                 {'overjoyed': 15, 'couldnt': 11, 'afford': 10, 'gift': 4, 'she': 3, 'get': 2, 'wanted': 2, 'the': 1, 'felt': 1}
# 55                                                                                                                                                   {'cop': 10, 'this': 6, 'the': 4, 'work': 4, 'hard': 4, 'day': 4, 'missus': 3, 'in': 3, 'food': 2, 'on': 2, 'table': 2, 'from': 2, 'out': 2, 'i': 1, 'put': 1}

# %%
# -- choose top 20 important words per class -- 
idiom_final = final[final['label']=='idiom']['all_words'].tolist()
sarcasm_final = final[final['label']=='sarcasm']['all_words'].tolist()
metaphor_final = final[final['label']=='metaphor']['all_words'].tolist()
simile_final = final[final['label']=='simile']['all_words'].tolist()

agg_idiom_final = {}
agg_sarcasm_final = {}
agg_metaphor_final = {}
agg_simile_final = {}

for dictionary in idiom_final:
    agg_idiom_final.update(dictionary)
for dictionary in sarcasm_final:
    agg_sarcasm_final.update(dictionary)
for dictionary in metaphor_final:
    agg_metaphor_final.update(dictionary)
for dictionary in simile_final:
    agg_simile_final.update(dictionary)

# %%
agg_idiom_final = {k: v for k, v in sorted(agg_idiom_final.items(), key=lambda item: item[1], reverse=True)[:20]}
agg_sarcasm_final = {k: v for k, v in sorted(agg_sarcasm_final.items(), key=lambda item: item[1], reverse=True)[:20]}
agg_metaphor_final = {k: v for k, v in sorted(agg_metaphor_final.items(), key=lambda item: item[1], reverse=True)[:20]}
agg_simile_final = {k: v for k, v in sorted(agg_simile_final.items(), key=lambda item: item[1], reverse=True)[:20]}

# %%
print(agg_idiom_final)
print(agg_sarcasm_final)
print(agg_metaphor_final)
print(agg_simile_final)
# Out:
# {'sink': 15, 'leak': 15, 'full': 15, 'duck': 14, 'cut': 14, 'nth': 14, 'swim': 14, 'beans': 14, 'broad': 14, 'beam': 14, 'lame': 13, 'bag': 13, 'baggage': 12, 'dried': 12, 'degree': 12, 'hand': 12, 'bear': 11, 'flow': 11, 'smell': 11, 'of': 11}
# {'overjoyed': 15, 'grateful': 14, 'pleasant': 14, 'great': 13, 'praised': 13, 'roses': 12, 'crashed': 12, 'excited': 12, 'vomiting': 12, 'myself': 12, 'not': 11, 'no': 11, 'hero': 11, 'terrible': 11, 'proud': 11, 'drops': 11, 'happy': 11, 'couldnt': 11, 'deal': 10, 'mistake': 10}
# {'toppled': 15, 'rose': 15, 'fell': 14, 'shoot': 14, 'burning': 13, 'gravely': 13, 'never': 13, 'cure': 13, 'desire': 12, 'fertilize': 12, 'the': 12, 'flicked': 12, 'darkness': 12, 'spirits': 12, 'prescribes': 12, 'behind': 11, 'ravaged': 11, 'dwell': 11, 'leak': 10, 'speed': 9}
# {'as': 17, 'smooth': 14, 'tough': 13, 'dummies': 13, 'crocodile': 13, 'snowman': 13, 'cancer': 12, 'glass': 12, 'affectionate': 12, 'oak': 11, 'an': 11, 'angel': 11, 'dream': 11, 'gift': 10, 'like': 10, 'planted': 10, 'deflated': 10, 'day': 10, 'fantastical': 10, 'washboard': 9}

# %%
with open('../results/human_annotation/reasons_idiom.txt', 'w') as f:
    for k, v in agg_idiom_final.items():
        print(k, file=f)
        
with open('../results/human_annotation/reasons_sarcasm.txt', 'w') as f:
    for k, v in agg_sarcasm_final.items():
        print(k, file=f)
        
with open('../results/human_annotation/reasons_metaphor.txt', 'w') as f:
    for k, v in agg_metaphor_final.items():
        print(k, file=f)
        
with open('../results/human_annotation/reasons_simile.txt', 'w') as f:
    for k, v in agg_simile_final.items():
        print(k, file=f)
